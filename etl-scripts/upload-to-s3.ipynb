# %%
import os
import boto3

def upload_files_to_s3(bucket_name, folder_path):
    # Initialize S3 client
    s3_client = boto3.client('s3')

    # Iterate through all files in the folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            s3_key = os.path.relpath(file_path, folder_path)  # S3 key relative to folder_path
            
            # Upload file to S3
            s3_client.upload_file(file_path, bucket_name, s3_key)
            print(f"Uploaded {file_path} to s3://{bucket_name}/{s3_key}")

# Example usage
bucket_name = "nyc-yellow-taxi-parquetdata"
folder_path = "raw"  # Path to the raw folder
upload_files_to_s3(bucket_name, folder_path)
# Out:
# ---------------------------------------------------------------------------
# NoSuchBucket                              Traceback (most recent call last)
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/boto3/s3/transfer.py:372, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     371 try:
# --> 372     future.result()
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/s3transfer/futures.py:111, in TransferFuture.result(self)
#     107 try:
#     108     # Usually the result() method blocks until the transfer is done,
#     109     # however if a KeyboardInterrupt is raised we want want to exit
#     110     # out of this and propagate the exception.
# --> 111     return self._coordinator.result()
#     112 except KeyboardInterrupt as e:
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/s3transfer/futures.py:272, in TransferCoordinator.result(self)
#     271 if self._exception:
# --> 272     raise self._exception
#     273 return self._result
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/s3transfer/tasks.py:142, in Task.__call__(self, ctx)
#     141     if not self._transfer_coordinator.done():
# --> 142         return self._execute_main(kwargs)
#     143 except Exception as e:
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/s3transfer/tasks.py:165, in Task._execute_main(self, kwargs)
#     163 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 165 return_value = self._main(**kwargs)
#     166 # If the task is the final task, then set the TransferFuture's
#     167 # value to the return value from main().
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/s3transfer/tasks.py:351, in CreateMultipartUploadTask._main(self, client, bucket, key, extra_args)
#     350 # Create the multipart upload.
# --> 351 response = client.create_multipart_upload(
#     352     Bucket=bucket, Key=key, **extra_args
#     353 )
#     354 upload_id = response['UploadId']
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/botocore/client.py:570, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     569 # The "self" in this scope is referring to the BaseClient.
# --> 570 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/botocore/client.py:1031, in BaseClient._make_api_call(self, operation_name, api_params)
#    1030     error_class = self.exceptions.from_code(error_code)
# -> 1031     raise error_class(parsed_response, operation_name)
#    1032 else:
#
# NoSuchBucket: An error occurred (NoSuchBucket) when calling the CreateMultipartUpload operation: The specified bucket does not exist
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# Cell In[1], line 21
#      19 bucket_name = "your-s3-bucket-name"
#      20 folder_path = "raw"  # Path to the raw folder
# ---> 21 upload_files_to_s3(bucket_name, folder_path)
#
# Cell In[1], line 15, in upload_files_to_s3(bucket_name, folder_path)
#      12 s3_key = os.path.relpath(file_path, folder_path)  # S3 key relative to folder_path
#      14 # Upload file to S3
# ---> 15 s3_client.upload_file(file_path, bucket_name, s3_key)
#      16 print(f"Uploaded {file_path} to s3://{bucket_name}/{s3_key}")
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/boto3/s3/inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)    172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File ~/anaconda3/envs/DLProject/lib/python3.12/site-packages/boto3/s3/transfer.py:378, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#     377 except ClientError as e:
# --> 378     raise S3UploadFailedError(
#     379         "Failed to upload {} to {}: {}".format(
#     380             filename, '/'.join([bucket, key]), e
#     381         )
#     382     )
#
# S3UploadFailedError: Failed to upload raw/yellow_tripdata_2023-06.parquet to your-s3-bucket-name/yellow_tripdata_2023-06.parquet: An error occurred (NoSuchBucket) when calling the CreateMultipartUpload operation: The specified bucket does not exist
